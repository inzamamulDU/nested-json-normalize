# %%
import pandas as pd
df = pd.read_csv("surbl.csv",encoding = "UTF-8")
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (456,457,458,488,489,490,491,492,493,494,495,496,497,498,499,500,512,513,514,515,523,524,525,526,527,528,529,530,538,539,540,548,549,550,558,559,560,568,569,570,578,579) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#       0  version  stats_id           stats_domain  stats_pageviews  \
# 0     0        3       NaN  ww16.bentleygoods.com                0
# 1     0        3       NaN       aktiv-consult.ru                0
# 2     0        3       NaN    lenconmarketing.com                0
# 3     0        3       NaN          rizedenal.com                0
# 4     0        3       NaN   glitteraccessory.net                0
# ...  ..      ...       ...                    ...              ...
# 1765  0        3       NaN       ablararealty.com                0
# 1766  0        3       NaN   evalindsayhealth.com                0
# 1767  0        3       NaN        kwredginger.com                0
# 1768  0        3       NaN   bettershopguide.info                0
# 1769  0        3       NaN        manjappada.club                0
#
#      stats_last_checked_timestamp  stats_create_timestamp  stats_pagesniffs  \
# 0             2021-01-05 11:59:57                     NaN                 0
# ...
